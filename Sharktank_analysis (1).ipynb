# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Shark Tank US dataset.csv')
#STEP 1: Understand the Dataset
df.head()
# Out:
#    Season Number              Startup Name  Episode Number  Pitch Number  \
# 0              1            AvaTheElephant               1             1
# 1              1         MrTod'sPieFactory               1             2
# 2              1                   Wispots               1             3
# 3              1  CollegeFoxesPackingBoxes               1             4
# 4              1                  IonicEar               1             5
#
#   Season Start Season End Original Air Date             Industry  \
# 0     9-Aug-09   5-Feb-10          9-Aug-09      Health/Wellness
# 1     9-Aug-09   5-Feb-10          9-Aug-09    Food and Beverage
# 2     9-Aug-09   5-Feb-10          9-Aug-09    Business Services
# 3     9-Aug-09   5-Feb-10          9-Aug-09       Lifestyle/Home
# 4     9-Aug-09   5-Feb-10          9-Aug-09  Technology/Software
#
#                               Business Description  \
# 0           Ava The Elephant - Baby and Child Care
# ...

# %%
df.shape
# Out:
# (1485, 54)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 53 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Season Number                       1485 non-null   int64
#  1   Startup Name                        1485 non-null   object
#  2   Episode Number                      1485 non-null   int64
#  3   Pitch Number                        1485 non-null   int64
#  4   Season Start                        1485 non-null   object
#  5   Season End                          1441 non-null   object
#  6   Original Air Date                   1485 non-null   object
#  7   Industry                            1485 non-null   object
#  8   Business Description                1485 non-null   object
#  9   Company Website                     961 non-null    object
#  10  Pitchers Gender                     1476 non-null   object
# ...

# %%
#STEP 2: Data Quality Assessment

df.isnull().sum().sort_values(ascending=False)
# Out:
# Deal Has Conditions                   1481
# Advisory Shares Equity                1479
# Loan                                  1425
# Royalty Deal                          1392
# Daymond John Investment Equity        1359
# Daymond John Investment Amount        1359
# Kevin O Leary Investment Equity       1347
# Kevin O Leary Investment Amount       1347
# Robert Herjavec Investment Equity     1347
# Robert Herjavec Investment Amount     1347
# Barbara Corcoran Investment Equity    1339
# Barbara Corcoran Investment Amount    1339
# Guest Present                         1338
# Guest Name                            1332
# Guest Investment Amount               1332
# Guest Investment Equity               1332
# Lori Greiner Investment Equity        1245
# Lori Greiner Investment Amount        1245
# Mark Cuban Investment Equity          1222
# Mark Cuban Investment Amount          1222
# Pitchers Average Age                   938
# Pitchers City                          667
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Original Air Date']=pd.to_datetime(df['Original Air Date'])
# Out:
# C:\Users\thesi\AppData\Local\Temp\ipykernel_2524\1486867306.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Original Air Date']=pd.to_datetime(df['Original Air Date'])

# %%
df['Original Air Date'].head(10)
# Out:
# 0   2009-08-09
# 1   2009-08-09
# 2   2009-08-09
# 3   2009-08-09
# 4   2009-08-09
# 5   2009-08-16
# 6   2009-08-16
# 7   2009-08-16
# 8   2009-08-16
# 9   2009-08-16
# Name: Original Air Date, dtype: datetime64[ns]

# %%
df['Original Air Date']=pd.to_datetime(df['Original Air Date'],format='%y-%m-%d')

# %%
df.info()   #now change datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 53 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Season Number                       1485 non-null   int64
#  1   Startup Name                        1485 non-null   object
#  2   Episode Number                      1485 non-null   int64
#  3   Pitch Number                        1485 non-null   int64
#  4   Season Start                        1485 non-null   object
#  5   Season End                          1441 non-null   object
#  6   Original Air Date                   1485 non-null   datetime64[ns]
#  7   Industry                            1485 non-null   object
#  8   Business Description                1485 non-null   object
#  9   Company Website                     961 non-null    object
#  10  Pitchers Gender                     1476 non-null   object
# ...

# %%
print(df['Original Air Date'].sample(20).tolist()) # why this check because there are diffrent type of format in columns
# Out:
# [Timestamp('2020-03-06 00:00:00'), Timestamp('2022-03-25 00:00:00'), Timestamp('2012-03-16 00:00:00'), Timestamp('2011-04-29 00:00:00'), Timestamp('2025-09-24 00:00:00'), Timestamp('2013-11-15 00:00:00'), Timestamp('2019-04-21 00:00:00'), Timestamp('2022-05-06 00:00:00'), Timestamp('2015-03-13 00:00:00'), Timestamp('2013-09-20 00:00:00'), Timestamp('2026-01-14 00:00:00'), Timestamp('2024-03-15 00:00:00'), Timestamp('2020-03-27 00:00:00'), Timestamp('2025-05-09 00:00:00'), Timestamp('2013-01-04 00:00:00'), Timestamp('2023-01-27 00:00:00'), Timestamp('2017-11-05 00:00:00'), Timestamp('2018-01-21 00:00:00'), Timestamp('2014-09-26 00:00:00'), Timestamp('2013-09-20 00:00:00')]

# %%
df['Original Air Date'].unique()[:20]
# Out:
# <DatetimeArray>
# ['2009-08-09 00:00:00', '2009-08-16 00:00:00', '2009-08-23 00:00:00',
#  '2009-08-30 00:00:00', '2009-09-06 00:00:00', '2009-09-13 00:00:00',
#  '2009-09-29 00:00:00', '2009-10-06 00:00:00', '2009-10-13 00:00:00',
#  '2009-10-20 00:00:00', '2010-01-08 00:00:00', '2010-01-15 00:00:00',
#  '2010-01-29 00:00:00', '2010-02-05 00:00:00', '2011-03-20 00:00:00',
#  '2011-03-25 00:00:00', '2011-04-01 00:00:00', '2011-04-08 00:00:00',
#  '2011-04-15 00:00:00', '2011-04-22 00:00:00']
# Length: 20, dtype: datetime64[ns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Guest Present'].head(10)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: Guest Present, dtype: float64

# %%
df['Guest Present'].tail(10)
# Out:
# 1475    2.0
# 1476    2.0
# 1477    2.0
# 1478    2.0
# 1479    2.0
# 1480    2.0
# 1481    2.0
# 1482    2.0
# 1483    2.0
# 1484    2.0
# Name: Guest Present, dtype: float64

# %%
df['Guest Present'].sample(10)  # so there are three value in guest present so convert into int
#and remove Nan values first verify actual mean of Nan,1 and 2
# Out:
# 1070   NaN
# 784    NaN
# 1246   NaN
# 1186   NaN
# 467    NaN
# 36     NaN
# 90     NaN
# 1314   NaN
# 1171   NaN
# 817    NaN
# Name: Guest Present, dtype: float64

# %%
df['Guest Present'].value_counts(dropna=False)
# Out:
# Guest Present
# NaN    1338
# 1.0     123
# 2.0      24
# Name: count, dtype: int64

# %%
df['Guest_Present_Binary'] = df['Guest Present'].notna().astype('int8') #so its basically convert nan=0 and 1=1,2=1 that mean 0=no gest and 1=present guest

# %%
df.info()
df['Guest_Present_Binary'].head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Season Number                       1485 non-null   int64
#  1   Startup Name                        1485 non-null   object
#  2   Episode Number                      1485 non-null   int64
#  3   Pitch Number                        1485 non-null   int64
#  4   Season Start                        1485 non-null   object
#  5   Season End                          1441 non-null   object
#  6   Original Air Date                   1485 non-null   datetime64[ns]
#  7   Industry                            1485 non-null   int64
#  8   Business Description                1485 non-null   object
#  9   Company Website                     961 non-null    object
#  10  Pitchers Gender                     1476 non-null   object
# ...

# %%
#Categorize Features

df['Industry'] = le.fit_transform(df['Industry'])

# %%
df['Industry'].sample(5)
# Out:
# 651     2
# 938     6
# 497     6
# 564     9
# 1124    6
# Name: Industry, dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Season Number', 'Startup Name', 'Episode Number', 'Pitch Number', 'Season Start', 'Season End', 'Original Air Date', 'Industry', 'Business Description', 'Company Website', 'Pitchers Gender', 'Pitchers Average Age', 'Entrepreneur Names', 'Multiple Entrepreneurs', 'US Viewership', 'Original Ask Amount', 'Original Offered Equity', 'Valuation Requested', 'Got Deal', 'Total Deal Amount', 'Total Deal Equity', 'Deal Valuation', 'Number of Sharks in Deal', 'Investment Amount Per Shark', 'Equity Per Shark', 'Royalty Deal', 'Advisory Shares Equity', 'Loan', 'Deal Has Conditions', 'Barbara Corcoran Investment Amount', 'Barbara Corcoran Investment Equity', 'Mark Cuban Investment Amount', 'Mark Cuban Investment Equity', 'Lori Greiner Investment Amount', 'Lori Greiner Investment Equity', 'Robert Herjavec Investment Amount', 'Robert Herjavec Investment Equity', 'Daymond John Investment Amount', 'Daymond John Investment Equity', 'Kevin O Leary Investment Amount', 'Kevin O Leary Investment Equity',
# ...

# %%
numerical_features = df.select_dtypes(
    include=['int64','float64']
).columns.tolist()

categorical_features = df.select_dtypes(
    include=['object']
).columns.tolist()

date_features = df.select_dtypes(
    include=['datetime64']
).columns.tolist()

binary_features = []

for col in df.columns:
    if df[col].nunique() == 2:
        binary_features.append(col)

# %%
print("Numerical Features:")
print(numerical_features)

print("\nCategorical Features:")
print(categorical_features)

print("\nDate Features:")
print(date_features)

print("\nBinary Features:")
print(binary_features)
# Out:
# Numerical Features:
# ...

# %%
#if you work with small data set than you can create your dataset that contain only important data and you can work on it
#and also make it automate process
data_dictionary = pd.DataFrame({
    'Column Name': df.columns,
    'Data Type': df.dtypes.astype(str),
    'Missing Values': df.isnull().sum(),
    'Unique Values': df.nunique()
})
data_dictionary
# Out:
#                                              Column Name Data Type  \
# Season Number                              Season Number     int64
# Startup Name                                Startup Name    object
# Episode Number                            Episode Number     int64
# Pitch Number                                Pitch Number     int64
# Season Start                                Season Start    object
# ...                                                  ...       ...
# Pitchers City_New York            Pitchers City_New York      bool
# Pitchers City_Other                  Pitchers City_Other      bool
# Pitchers City_Portland            Pitchers City_Portland      bool
# Pitchers City_San Diego          Pitchers City_San Diego      bool
# Pitchers City_San Francisco  Pitchers City_San Francisco      bool
#
#                              Missing Values  Unique Values
# Season Number                             0             17
# ...

# %%
#Handle Missing Values 

df['Pitchers Average Age'] = (
    df['Pitchers Average Age']
    .fillna(
        df['Pitchers Average Age'].median()
    )
)

# %%
df['Pitchers Average Age'].sample(10)
# Out:
# 975        NaN
# 1139    Middle
# 1244    Middle
# 188        NaN
# 1393    Middle
# 510        NaN
# 246        NaN
# 1046     Young
# 806        NaN
# 223        NaN
# Name: Pitchers Average Age, dtype: object

# %%
print(df['Pitchers Average Age'].value_counts(dropna=False))
# Out:
# Pitchers Average Age
# NaN       938
# Middle    492
# Young      41
# Old        14
# Name: count, dtype: int64

# %%
df['Pitchers Average Age'] = df['Pitchers Average Age'].fillna('Unknown')

# %%
print(df['Pitchers Average Age'].value_counts())
# Out:
# Pitchers Average Age
# Unknown    938
# Middle     492
# Young       41
# Old         14
# Name: count, dtype: int64

# %%
age_mapping = {
    'Unknown': 0,
    'Young': 1,
    'Middle': 2,
    'Old': 3
}

df['Pitchers Average Age'] = df['Pitchers Average Age'].map(age_mapping)

# %%
# Detect Outliers

# %%
df.describe()
# Out:
#        Season Number  Episode Number  Pitch Number  \
# count    1485.000000     1485.000000   1485.000000
# mean        9.039057       12.160269    743.000000
# min         1.000000        1.000000      1.000000
# 25%         5.000000        6.000000    372.000000
# 50%         9.000000       11.000000    743.000000
# 75%        13.000000       18.000000   1114.000000
# max        17.000000       29.000000   1485.000000
# std         4.421198        7.335797    428.826888
#
#                    Original Air Date     Industry  Pitchers Average Age  \
# count                           1485  1485.000000                   0.0
# mean   2018-01-30 22:24:58.181818112     6.535354                   NaN
# min              2009-08-09 00:00:00     0.000000                   NaN
# 25%              2014-05-09 00:00:00     4.000000                   NaN
# 50%              2017-11-05 00:00:00     6.000000                   NaN
# ...

# %%
sns.boxplot(
    x=df['Original Ask Amount']
)
# Out:
# <Axes: xlabel='Original Ask Amount'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))

sns.boxplot(
    x=df['Original Ask Amount']
)

plt.title("Outliers in Original Ask Amount")
plt.show()

# %%
Q1 = df['Original Ask Amount'].quantile(0.25)

Q3 = df['Original Ask Amount'].quantile(0.75)

IQR = Q3 - Q1
print("Q1:",Q1)
print("Q3:",Q3)
print("IQR:",IQR)
# Out:
# Q1: 100000.0
# Q3: 343000.0
# IQR: 243000.0

# %%
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
print(lower,upper)
# Out:
# -264500.0 707500.0

# %%
outliers = df[
    (df['Original Ask Amount'] < lower) |
    (df['Original Ask Amount'] > upper)
]

outliers
# Out:
#       Season Number          Startup Name  Episode Number  Pitch Number  \
# 2                 1               Wispots               1             3
# 4                 1              IonicEar               1             5
# 41                1           VirtuSphere               9            42
# 107               3        VegasMagicShow               2           108
# 143               3  TheSullivanGenerator              11           144
# ...             ...                   ...             ...           ...
# 1356             15            RoboBurger              21          1357
# 1364             16                TRUFIT               1          1365
# 1367             16            BucketGolf               2          1368
# 1414             16              Blackdot              14          1415
# 1443             17              Pelagion               1          1444
#
#      Season Start Season End Original Air Date  Industry  \
# ...

# %%
print("Number of Outliers:",len(outliers))
# Out:
# Number of Outliers: 79

# %%
df['Original Ask Amount']
# Out:
# 0         50000.0
# 1        460000.0
# 2       1200000.0
# 3        250000.0
# 4       1000000.0
#           ...
# 1480     250000.0
# 1481          NaN
# 1482          NaN
# 1483          NaN
# 1484          NaN
# Name: Original Ask Amount, Length: 1485, dtype: float64

# %%
#Univariate Analysis  you can deeply each column see and analysis
df['Industry'].value_counts()   #this is category data apply it
sns.countplot(
    y='Industry',
    data=df
)
# Out:
# <Axes: xlabel='count', ylabel='Industry'>

# %%
df['Valuation Requested'].describe()
#most numeric data apply on histogram
sns.histplot(        
    df['Valuation Requested']
)
# Out:
# <Axes: xlabel='Valuation Requested', ylabel='Count'>

# %%
#Bivariate Analysis  ok so most important acording to target column and depend on other column to relationship like
#two veriable

# %%
pd.crosstab(
    df['Industry'],
    df['Got Deal']
)
# Out:
# Got Deal  0.0  1.0
# Industry
# 0           4   13
# 1          20   22
# 2          46   89
# 3           9   10
# 4         101  137
# 5          56   95
# 6         124  195
# 7           7    7
# 8          28   43
# 9          85  176
# 10          5    7
# 11         10   24
# 12         27   36
# 13         31   39
# 14          6    5
# 15          8   16

# %%
industry_deal = pd.crosstab(
    df['Industry'],
    df['Got Deal'],
    normalize='index'
)*100

industry_deal.round(2)
# Out:
# Got Deal    0.0    1.0
# Industry
# 0         23.53  76.47
# 1         47.62  52.38
# 2         34.07  65.93
# 3         47.37  52.63
# 4         42.44  57.56
# 5         37.09  62.91
# 6         38.87  61.13
# 7         50.00  50.00
# 8         39.44  60.56
# 9         32.57  67.43
# 10        41.67  58.33
# 11        29.41  70.59
# 12        42.86  57.14
# 13        44.29  55.71
# 14        54.55  45.45
# 15        33.33  66.67

# %%
# Which industries get deals most? 
sns.boxplot(
    x='Got Deal',
    y='Original Ask Amount',
    data=df
)
# Out:
# <Axes: xlabel='Got Deal', ylabel='Original Ask Amount'>

# %%
# ok so basically you can ask industry and deal seccess rate ?
industry_deal.plot(
    kind='bar',
    figsize=(10,5)
)

plt.title("Industry vs Deal Success")
plt.ylabel("Percentage")
plt.show()

# %%
# Do smaller asks succeed more?
plt.figure(figsize=(8,5))

sns.boxplot(
    x='Got Deal',
    y='Original Ask Amount',
    data=df
)

plt.title("Ask Amount vs Deal Success")
plt.show()

# %%
#Valuation Requested vs Got Deal
sns.boxplot(
    x='Got Deal',
    y='Valuation Requested',
    data=df
)

plt.title("Valuation vs Deal Success")
plt.show()

# %%
#Industry vs Ask Amount    you can find which industry is boom 
plt.figure(figsize=(12,6))

sns.boxplot(
    x='Industry',
    y='Original Ask Amount',
    data=df
)

plt.xticks(rotation=45)

plt.show()

# %%
ax = sns.countplot(
    x='Kevin O Leary Present',   # you can show diffrent shark when present or not thair acording to predict deal or not ?
    hue='Got Deal',
    data=df
)

for container in ax.containers:
    ax.bar_label(container)

plt.title('Kevin o leary present in show')
plt.show()

# %%
# Do teams perform better than solo founders?    so there are more chances if you work on team
pd.crosstab(
    df['Multiple Entrepreneurs'],
    df['Got Deal'],
    normalize='index'
)*100
# 1. Industry vs Got Deal
# 2. Ask Amount vs Got Deal
# 3. Valuation vs Got Deal
# 4. Age Group vs Got Deal
# 5. Multiple Entrepreneurs vs Got Deal
# 6. Gender vs Got Deal
# 7. Correlation Heatmap    you can also try diffrent columns to compare each other can relate
# Out:
# Got Deal                0  1
# Multiple Entrepreneurs
# 0                      43 57
# 1                      31 69

# %%
#Feature Engineering   also try Deal Difference,Equity Change,Deal Success Flag
df['Valuation Requested'].head(10)
df['Valuation'] = (
    df['Original Ask Amount']
    /
    (df['Original Offered Equity'] / 100)
)

df['Valuation'].head(10)
# Out:
# 0      333,333
# 1    4,600,000
# 2   12,000,000
# 3    1,000,000
# 4    6,666,667
# 5    3,333,333
# 6    2,500,000
# 7    5,000,000
# 8    1,000,000
# 9      500,000
# Name: Valuation, dtype: float64

# %%
np.isinf(X).sum()   # check infinite values in dataset this is accured in model creation
# Out:
# Season Number                  0
# Episode Number                 0
# Pitch Number                   0
# Industry                       0
# Pitchers Average Age           0
#                               ..
# Pitchers City_San Francisco    0
# Valuation                      0
# Equity_Ratio                   0
# Pitchers Gender_Male           0
# Pitchers Gender_Mixed Team     0
# Length: 65, dtype: int64

# %%
# "At this stage, our dataset has been fully cleaned, transformed, and enriched through feature engineering.
# We have addressed missing values, corrected data types, handled outliers, explored relationships between variables,
# and created new business-focused features. The resulting dataset is now analytics-ready and can be used for advanced reporting,
# dashboard development, and predictive modeling."

# %%
# Dataset Overview using claud for it boost your ability

# 1,485 pitches × 54 columns — covering shark presence, investment amounts/equity per shark, industry, founder demographics, and deal outcomes.
# Zero duplicate rows, but heavy missingness in shark-specific columns (e.g., "Daymond John Investment Equity" missing in 1,359 rows). That's expected — those are NaN when that specific shark didn't invest, not bad data.

# Step 1 — Data Cleaning

# Date fixing: "Original Air Date" was stored as mixed-format strings, so you converted it with pd.to_datetime(), verifying the conversion by sampling 20 random values.
# Duplicate check: confirmed df.duplicated().sum() = 0.
# Missing value audit: ran isnull().sum() sorted descending to separate "structurally missing" (shark didn't invest) from "actually missing" (e.g., Pitchers Average Age missing in 938/1485 rows).
# Guest Present column: had 3 states (NaN / 1 / 2) so you collapsed it into a clean binary flag — Guest_Present_Binary (0 = no guest, 1 = guest present).

# Step 2 — Preprocessing & Feature Engineering

# Industry: label-encoded into numeric codes for modeling.
# Pitchers Average Age: filled missing values, then bucketed into ordinal categories (Unknown/Young/Middle/Old) and mapped to 0–3.
# Outlier detection: used the IQR method on "Original Ask Amount" — found 79 outlier pitches (extreme high/low asks), visualized with a boxplot.
# New engineered feature: Valuation = Ask Amount / (Offered Equity / 100) — reconstructs the implied company valuation from the deal terms.
# Built a feature-type map (numerical / categorical / date / binary) and a data dictionary — a nice habit to show in a video since it documents the dataset for anyone reusing it.

# Step 3 — EDA (Univariate + Bivariate)

# Univariate: industry distribution (countplot), "Valuation Requested" distribution (histogram).
# Bivariate, against the target Got Deal:

# Industry vs deal rate (crosstab, normalized)
# Ask Amount vs deal outcome (boxplot)
# Valuation vs deal outcome (boxplot)
# Shark presence (e.g., Kevin O'Leary) vs deal outcome (countplot)
# Team size (solo vs multiple founders) vs deal outcome



# Key Insights to dataset and use for it model creation
# Teams out-perform solo founders. Solo founders got a deal 57% of the time; teams with multiple entrepreneurs got a deal 69% of the time — a meaningful ~12-point edge.
# Industry matters a lot. Deal-success rates across industries ranged roughly from the mid-40s% up to ~76% — some categories are simply more "fundable" on the show than others.
# Ask size and valuation both visibly separate "got deal" vs "no deal" groups in the boxplots — pitches with more reasonable asks/valuations tend to close more often (worth calling out the median shift between the two boxplots on screen).
# 79 pitches (~5% of the dataset) are statistical outliers in ask amount — these are the "ambitious" or "moonshot" pitches and skew averages, which is why you used the median (not mean) when filling Pitchers Average Age.
# Missingness itself is informative — most NaNs aren't "dirty data," they encode "this shark didn't invest," so blindly dropping rows would have destroyed real signal.

# %% [markdown]
# # -------next videos for create Dahboard using PowerBi  -------
